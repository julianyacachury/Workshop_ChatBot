# %% [markdown]
# #Chatbots Clásicos en python + telegram #
#
# ##por Exdata y el taller de datos##
# ![Logo - Claro (sin fondo).png](data:image/png;base64,...)
#
# ![WhatsApp Image 2025-05-30 at 21.10.14.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Proyecto Exacty#
# que es?
#
# de donde nace?
#
# quienes somos?
#
# somos arrojados a la existencia
#
# Lo que no conviene a la colemna no conviene a la abeja

# %% [markdown]
# # 1. Introducción y Casos de Uso
#
# ## **¿ Qué es un Chatbot clasico?**
# Un chatbot clásico es un programa que simula conversaciones humanas usando reglas predefinidas y patrones de reconocimiento de texto. A diferencia de los chatbots modernos con IA, estos funcionan con lógica condicional y expresiones regulares.
#
#
# #### 1. Chatbot de Atención al Cliente - E-commerce
# **Caso de uso**: Tienda online que vende productos tecnológicos
#
# **Flujo conversacional**:
# ```
# Usuario: "Hola"
# Bot: "¡Hola! Soy el asistente de TecnoTienda. ¿En qué puedo ayudarte?"
#      "1. Consultar productos"
#      "2. Estado de pedido"
#      "3. Devoluciones"
#      "4. Hablar con humano"
#
# Usuario: "1"
# Bot: "¿Qué tipo de producto buscas?"
#      "- Smartphones"
#      "- Laptops"
#      "- Accesorios"
#
# Usuario: "Smartphones"
# Bot: "Tenemos estos smartphones disponibles:"
#      "📱 iPhone 15 - $899"
#      "📱 Samsung Galaxy S24 - $799"
#      "📱 Google Pixel 8 - $699"
#      "¿Te interesa alguno en particular?"
# ```
#
# #### 2. Chatbot Empresarial - Recursos Humanos
# **Caso de uso**: Asistente interno para empleados
#
# **Flujo conversacional**:
# ```
# Empleado: "Buenos días"
# Bot: "¡Buenos días! Soy RH-Bot. ¿En qué puedo asistirte?"
#      "🏖️ Solicitar vacaciones"
#      "📋 Consultar políticas"
#      "💰 Info de nómina"
#      "🏥 Beneficios médicos"
#
# Empleado: "Quiero solicitar vacaciones"
# Bot: "Para solicitar vacaciones necesito:"
#      "1. Fechas deseadas (DD/MM/YYYY - DD/MM/YYYY)"
#      "2. Motivo (personal/familiar/médico)"
#      "Por favor, envía: VACACIONES [fecha inicio] [fecha fin] [motivo]"
#
# Empleado: "VACACIONES 15/06/2024 22/06/2024 personal"
# Bot: "✅ Solicitud registrada:"
#      "📅 Del 15/06/2024 al 22/06/2024"
#      "📝 Motivo: Personal"
#      "⏳ Estado: Pendiente de aprobación"
#      "Te notificaré cuando sea revisada por tu supervisor."
# ```
#
#
#
# #### 3. Chatbot de Servicios - Restaurante
# **Caso de uso**: Sistema de reservas y pedidos
#
# **Flujo conversacional**:
# ```
# Cliente: "Hola, quiero hacer una reserva"
# Bot: "¡Perfecto! Para tu reserva en Restaurante Bella Vista:"
#      "👥 ¿Para cuántas personas?"
#
# Cliente: "4 personas"
# Bot: "Excelente, mesa para 4 personas."
#      "📅 ¿Qué día prefieres? (formato DD/MM/YYYY)"
#
# Cliente: "25/12/2024"
# Bot: "⏰ ¿A qué hora te gustaría cenar?"
#      "Horarios disponibles para el 25/12:"
#      "- 19:00"
#      "- 20:30"
#      "- 22:00"
#
# Cliente: "20:30"
# Bot: "📋 Resumen de tu reserva:"
#      "👥 4 personas"
#      "📅 25/12/2024"
#      "⏰ 20:30"
#      "📱 ¿Podrías confirmar tu número de teléfono?"
# ```

# %% [markdown]
# Operador **in** en *Python* :
#
# Devuelve un booleano -> Verdadero o Falso.

# %%
my_list = [1, 2, 3, 4, 5]
print(3 in my_list)  # Output: True
print(6 in my_list)  # Output: False

my_string = "hello"
print("e" in my_string)  # Output: True
print("z" in my_string)  # Output: False
# Out:
# True
# False
# True
# False

# %% [markdown]
# **Ejercicio :**
#
# 1.   Elemento de la lista
# 2.   Elemento de la lista

# %%
numeros = [1, 2, 3, 4, 5]
n=input("Ingresa un numero: ")
#Terminar para que devuelva si el numero ingresado esta en la lista
#...

if n in numeros:
    print(f"El número {n} está en la lista.")
else:
    print(f"El número {n} no está en la lista.")
# Out:
# Ingresa un numero: 1
# El número 1 no está en la lista.

# %%
entrada = input("Escribí un comando: ")
comandos_validos = ["hola", "adiós", "ayuda"]
#terminar
#if ... :
if entrada in comandos_validos:
    print(f"El comando {entrada} es válido.")
else:
    print(f"El comando {entrada} no es válido.")
# Out:
# Escribí un comando: hola
# El comando hola es válido.

# %% [markdown]
# Solucíones:

# %%
# Ejercicios 1
numeros = [1, 2, 3, 4, 5]
n=input("Ingresa un numero: ")

# Forma 1
if any(int(n) == num for num in numeros):
    print(f"El número {n} está en la lista.")
else:
    print(f"El número {n} no está en la lista.")

# Forma 2
for num in numeros:
    if  int(n) == num:
        print(f"El número {n} está en la lista.")
        break
else:
    print(f"El número {n} no está en la lista.")

# Ejercico 2.
# Es analogo pero con strings.

# %% [markdown]
# # 2. Herramientas y Fundamentos técnicos.
#
# # 2.1 Declaración de condicionales.
#
# Los chatbots clásicos funcionan principalmente con lógica condicional.  Entra cuchillo salen tripas.

# %%
# Estructura simple del uso de if Statements para un Chatbot
mensaje_usuario = input("Usuario: ").lower()

if "hola" in mensaje_usuario:
    print("Bot: ¡Hola! Andres!")
elif "adiós" in mensaje_usuario or "bye" in mensaje_usuario:
    print("Bot: ¡Nos vemos maquinola!")
else:
    print("Bot: Que decis Walter? No se entiende")
# Out:
# Usuario: como se llama mi mama
# Bot: Que decis Walter? No se entiende

# %%
# Manejo de Multiples condiciones.
def procesar_saludo(mensaje):
    saludos = ["hola", "buenos días", "buenas tardes", "hey", "hi","chao"]
    mensaje_lower = mensaje.lower()

    for saludo in saludos:
        if saludo in mensaje_lower:
            return "¡Hola! ¿En qué puedo ayudarte?"
    return None

def procesar_despedida(mensaje):
    despedidas = ["adiós", "bye", "hasta luego", "nos vemos", "chao"]
    mensaje_lower = mensaje.lower()

    for despedida in despedidas:
        if despedida in mensaje_lower:
            return "¡Hasta pronto! Que tengas un buen día."
    return None

# %%
saludo = input("Bot: Hola como estas?:")
respuesta=procesar_saludo(saludo)
print(respuesta)
despedida= input("Bot:")
respuesta=procesar_despedida(despedida)
print(respuesta)
# Out:
# Bot: Hola como estas?:hola
# ¡Hola! ¿En qué puedo ayudarte?
# Bot:bye
# ¡Hasta pronto! Que tengas un buen día.

# %% [markdown]
# # Logica de Estados.
#
# Al cumplirse uno de los Statements el bot debe avanzar a otra parte de la conversación, esto se realiza indicandole el nuevo estado en el que debe encontrarse.

# %%
class EstadoChatbot:
    def __init__(self):
        self.contexto = "inicio"
        self.datos_usuario = {}

    def cambiar_contexto(self, nuevo_contexto):
        self.contexto = nuevo_contexto
        print(f"[DEBUG] Contexto cambiado a: {nuevo_contexto}")

# Ejemplo de uso
estado = EstadoChatbot()


def procesar_mensaje(mensaje, estado):
    if estado.contexto == "inicio":
        if "hola" in mensaje.lower():
            return "¡Hola! ¿En qué puedo ayudarte?"
        if "productos" in mensaje.lower():
            estado.cambiar_contexto("consultando_productos")
            return "¿Qué tipo de producto buscas?"

    # Ejercicio  definir una función que permita
    # consultar una base de productos por categoría.
    elif estado.contexto == "consultando_productos":
        # Lógica específica para consulta de productos
        if "limpieza" in mensaje.lower():
            return "Tenemos jabones, escobas, traperos. "
        if "tecnología" in mensaje.lower():
            return "Tenemos Android y Iphone si lo prefiere."

        return "Lo siento, no tenemos de eso..."

# %%
while True:
    mensaje_usuario = input("Usuario: ").lower()
    if mensaje_usuario == "salir":
        break
    respuesta = procesar_mensaje(mensaje_usuario, estado)
    print("Bot:", respuesta)
# Out:
# Usuario: productos
# Bot: Lo siento, no tenemos de eso...
# Usuario: productos
# Bot: Lo siento, no tenemos de eso...
# Usuario: Hola
# Bot: Lo siento, no tenemos de eso...
# Usuario: hola
# Bot: Lo siento, no tenemos de eso...
# Usuario: salir

# %% [markdown]
# 💡 Resumen:
# 1. Condicionales, nos sirven para capturar las intenciones del usuario.
# 2. Estados, nos ayudan a situarnos en un lugar de la conversación para poder organizar el flujo del mismo: Saber que devolver, que buscar, que mensaje enviar.

# %% [markdown]
# 2.2 Librería RE (Expresiones Regulares)
#
# Son un pseudo-lenguaje, muy útiles para encontrar información en el texto y buscar palabras mal escritas.
#
# Siempre revisar documentación:
# https://docs.python.org/3/library/re.html
#
# O consultar a nuestro querido amigo Claudio, Gepeto o su LLM de cabecera.

# %%
import re

# Ejemplo básico: buscar patrones
mensaje = "Mi teléfono es 12351-456-7890"
patron_telefono = r'\d{3}-\d{3}-\d{4}'
telefono = re.search(patron_telefono, mensaje)

if telefono:
    print(f"Teléfono encontrado: {telefono.group()}")
# Out:
# Teléfono encontrado: 351-456-7890

# %%
import re

class ExtractorPatrones:
    def __init__(self):
        # Patrones comunes
        self.patron_email = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
        self.patron_telefono = r'(\+?1?\d{9,15})'
        self.patron_fecha = r'\b(\d{1,2})/(\d{1,2})/(\d{4})\b'
        self.patron_hora = r'\b(\d{1,2}):(\d{2})\b'
        self.patron_numero = r'\b\d+\b'
        self.patron_dinero = r'\$\d+(?:\.\d{2})?'

    def extraer_email(self, texto):
        emails = re.findall(self.patron_email, texto)
        return emails[0] if emails else None

    def extraer_telefono(self, texto):
        telefonos = re.findall(self.patron_telefono, texto)
        return telefonos[0] if telefonos else None

    def extraer_fecha(self, texto):
        fechas = re.findall(self.patron_fecha, texto)
        if fechas:
            dia, mes, año = fechas[0]
            return f"{dia}/{mes}/{año}"
        return None

    def extraer_numeros(self, texto):
        return re.findall(self.patron_numero, texto)

# %%
# Ejemplo de uso
extractor = ExtractorPatrones()

mensaje_usuario = "Mi email es invalido@asd.com juanito@loslonosaurios.com y mi teléfono es 1234567890"
email = extractor.extraer_email(mensaje_usuario)
telefono = extractor.extraer_telefono(mensaje_usuario)

print(f"Email: {email}")
print(f"Teléfono: {telefono}")
# Out:
# Email: invalido@asd.com
# Teléfono: 1234567890

# %% [markdown]
# # Manejo de Intenciones buscando RE.

# %%
import re

class ManejadorIntenciones:
    def __init__(self):
        self.intenciones = {
            'saludo': [
                r'\b(hola|hello|hi|buenos días|buenas tardes|hey)\b',
                r'^(hola|hello|hi)$'
            ],
            'consulta_precio': [
                r'\b(precio|cost[ao]|cuánto|vale)\b.*\b(producto|artículo)\b',
                r'\b(cuánto cuesta|precio de)\b'
            ],
            'hacer_pedido': [
                r'\b(quiero|deseo|me gustaría)\b.*\b(comprar|pedir|ordenar)\b',
                r'\b(hacer un pedido|realizar pedido)\b'
            ],
            'consultar_estado': [
                r'\b(estado|dónde está|cuándo llega)\b.*\b(pedido|orden)\b',
                r'\bmis pedidos\b'
            ]
        }

    def detectar_intencion(self, mensaje):
        mensaje_lower = mensaje.lower()

        for intencion, patrones in self.intenciones.items():
            for patron in patrones:
                if re.search(patron, mensaje_lower, re.IGNORECASE):
                    return intencion

        return 'desconocida'

    def extraer_entidades(self, mensaje, intencion):
        entidades = {}

        if intencion == 'consulta_precio':
            # Buscar nombre del producto
            producto_match = re.search(r'precio de (.+?)(?:\?|$)', mensaje, re.IGNORECASE)
            if producto_match:
                entidades['producto'] = producto_match.group(1).strip()

        elif intencion == 'hacer_pedido':
            # Buscar cantidad y producto
            cantidad_match = re.search(r'(\d+)', mensaje)
            if cantidad_match:
                entidades['cantidad'] = int(cantidad_match.group(1))

        return entidades

# Ejemplo de uso
manejador = ManejadorIntenciones()

mensajes_prueba = [
    "¿Cual es el precio de el iPhone?",
    "Quiero comprar 2 laptops",
    "¿Dónde está mi pedido?",
    "Buenos días"
]

for mensaje in mensajes_prueba:
    intencion = manejador.detectar_intencion(mensaje)
    entidades = manejador.extraer_entidades(mensaje, intencion)
    print(f"Mensaje: '{mensaje}'")
    print(f"Intención: {intencion}")
    print(f"Entidades: {entidades}")
    print("-" * 40)
# Out:
# Mensaje: '¿Cual es el precio de el iPhone?'
# Intención: consulta_precio
# Entidades: {'producto': 'el iPhone'}
# ----------------------------------------
# Mensaje: 'Quiero comprar 2 laptops'
# Intención: hacer_pedido
# Entidades: {'cantidad': 2}
# ----------------------------------------
# Mensaje: '¿Dónde está mi pedido?'
# Intención: consultar_estado
# Entidades: {}
# ----------------------------------------
# Mensaje: 'Buenos días'
# Intención: saludo
# Entidades: {}
# ----------------------------------------

# %% [markdown]
# ## 2.3 Capturar Input en Colab (Opcional)

# %%
def chatbot_consola():
    print("🤖 ¡Chatbot iniciado! Escribe 'salir' para terminar.")

    while True:
        mensaje_usuario = input("👤 Tú: ").strip()

        if mensaje_usuario.lower() in ['salir', 'exit', 'quit']:
            print("🤖 Bot: ¡Hasta luego!")
            break

        if not mensaje_usuario:
            print("🤖 Bot: Por favor, escribe algo.")
            continue

        # Procesar mensaje
        respuesta = procesar_mensaje_chatbot(mensaje_usuario)
        print(f"🤖 Bot: {respuesta}")

def procesar_mensaje_chatbot(mensaje):
    # Lógica del chatbot aquí
    if "hola" in mensaje.lower():
        return "¡Hola! ¿Cómo puedo ayudarte?"
    elif "adiós" in mensaje.lower():
        return "¡Hasta pronto!"
    else:
        return "Interesante, cuéntame más sobre eso."

# Ejecutar chatbot
if __name__ == "__main__":
    chatbot_consola()
# Out:
# 🤖 ¡Chatbot iniciado! Escribe 'salir' para terminar.
# 👤 Tú: Hola
# 🤖 Bot: ¡Hola! ¿Cómo puedo ayudarte?
# 👤 Tú: NO se vos decime
# 🤖 Bot: Interesante, cuéntame más sobre eso.
# 👤 Tú: ok
# 🤖 Bot: Interesante, cuéntame más sobre eso.
# 👤 Tú: salir
# 🤖 Bot: ¡Hasta luego!

# %% [markdown]
# ## Ejercicio.
#
# Implementar el clasificador de intenciones que ya vimos más arriba.
#
# Ayuda: En la función chabot consola podemos reutilizar la clase
# ```python
# class ManejadorDeIntenciones()
# ```
# antes del while true
# majeador = ManejadorDeIntenciones()

# %%
import re

class ManejadorIntenciones:
    def __init__(self):
        self.intenciones = {
            'saludo': [
                r'\b(hola|hello|hi|buenos días|buenas tardes|hey)\b',
                r'^(hola|hello|hi)$'
            ],
            'consulta_precio': [
                r'\b(precio|cost[ao]|cuánto|vale)\b.*\b(producto|artículo)\b',
                r'\b(cuánto cuesta|precio de)\b'
            ],
            'hacer_pedido': [
                r'\b(quiero|deseo|me gustaría)\b.*\b(comprar|pedir|ordenar)\b',
                r'\b(hacer un pedido|realizar pedido)\b'
            ],
            'consultar_estado': [
                r'\b(estado|dónde está|cuándo llega)\b.*\b(pedido|orden)\b',
                r'\bmis pedidos\b'
            ],
            'despedida': [
                r'\b(adiós|hasta luego|nos vemos|chau|bye)\b',
                r'^(adiós|bye)$'
            ]
        }

    def detectar_intencion(self, mensaje):
        mensaje_lower = mensaje.lower()

        for intencion, patrones in self.intenciones.items():
            for patron in patrones:
                if re.search(patron, mensaje_lower, re.IGNORECASE):
                    return intencion

        return 'desconocida'

    def extraer_entidades(self, mensaje, intencion):
        entidades = {}

        if intencion == 'consulta_precio':
            # Buscar nombre del producto
            producto_match = re.search(r'precio de (.+?)(?:\?|$)', mensaje, re.IGNORECASE)
            if producto_match:
                entidades['producto'] = producto_match.group(1).strip()

        elif intencion == 'hacer_pedido':
            # Buscar cantidad y producto
            cantidad_match = re.search(r'(\d+)', mensaje)
            if cantidad_match:
                entidades['cantidad'] = int(cantidad_match.group(1))
        return entidades

def chatbot_consola():
    print("🤖 ¡Chatbot iniciado! Escribe 'salir' para terminar.")

    # Crear instancia del manejador de intenciones
    manejador = ManejadorIntenciones()

    while True:
        mensaje_usuario = input("👤 Tú: ").strip()

        if mensaje_usuario.lower() in ['salir', 'exit', 'quit']:
            print("🤖 Bot: ¡Hasta luego!")
            break

        if not mensaje_usuario:
            print("🤖 Bot: Por favor, escribe algo.")
            continue

        # Procesar mensaje con el manejador de intenciones
        respuesta = procesar_mensaje_chatbot(mensaje_usuario, manejador)
        print(f"🤖 Bot: {respuesta}")

def procesar_mensaje_chatbot(mensaje, manejador):
    # Detectar la intención del mensaje
    intencion = manejador.detectar_intencion(mensaje)

    # Extraer entidades según la intención
    entidades = manejador.extraer_entidades(mensaje, intencion)

    match intencion:
        case 'saludo':
            return "¡Hola! ¿Cómo puedo ayudarte?"
        case 'consulta_precio':
          if 'producto' in entidades:
            producto = entidades['producto']
            return f"El precio de {producto} es $500. ¿Te interesa comprarlo?"
          else:
            return "¿De qué producto te gustaría conocer el precio?"
# Ejecutar chatbot
if __name__ == "__main__":
    chatbot_consola()
# Out:
# 🤖 ¡Chatbot iniciado! Escribe 'salir' para terminar.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-2607981b443c> in <cell line: 0>()
#      91 # Ejecutar chatbot
#      92 if __name__ == "__main__":
# ---> 93     chatbot_consola()
#
# <ipython-input-49-2607981b443c> in chatbot_consola()
#      59
#      60     while True:
# ---> 61         mensaje_usuario = input("👤 Tú: ").strip()
#      62
#      63         if mensaje_usuario.lower() in ['salir', 'exit', 'quit']:
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %% [markdown]
# ![Logo - Claro (sin fondo).png](data:image/png;base64,...)

# %% [markdown]
# # Maquetación de Flujos.

# %%
class FlujoChatbot:

    def __init__(self):
        self.estados = {
            'inicio': self.estado_inicio,
            'menu_principal': self.estado_menu_principal,
            'navegando_productos': self.estado_navegando_productos,
            'proceso_pedido': self.estado_proceso_pedido,
            'recopilando_datos': self.estado_recopilando_datos,
            'confirmacion': self.estado_confirmacion,
            'error_estado_desconocido': self.error_estado_desconocido,
            'recomendaciones': self.recomendaciones
        }

        self.estado_actual = 'inicio'
        self.datos_sesion = {}


        # Datos de ejemplo para el chatbot
        self.productos = {
            'smartphones': [
                {'nombre': 'iPhone 15', 'precio': 999},
                {'nombre': 'Samsung Galaxy S24', 'precio': 899}
            ],
            'laptops': [
                {'nombre': 'MacBook Air M3', 'precio': 1299},
                {'nombre': 'Dell XPS 13', 'precio': 1199}
            ]
        }

    def procesar_mensaje(self, mensaje):
        """Procesa mensaje según el estado actual"""
        print(f"\n🤖 [ESTADO ACTUAL]: {self.estado_actual}")
        print(f"📨 [MENSAJE RECIBIDO]: {mensaje}")
        print(f"💾 [DATOS SESIÓN]: {self.datos_sesion}")
        print("-" * 50)

        if self.estado_actual in self.estados:
            return self.estados[self.estado_actual](mensaje)
        else:
            return self.error_estado_desconocido()

    def cambiar_estado(self, nuevo_estado):
        """Cambia el estado del chatbot"""
        if nuevo_estado in self.estados:
            print(f"🔄 [CAMBIO DE ESTADO]: {self.estado_actual} → {nuevo_estado}")
            self.estado_actual = nuevo_estado
        else:
            print(f"❌ [ERROR] Estado desconocido: {nuevo_estado}")

    def estado_inicio(self, mensaje):
        print("📍 Ejecutando: estado_inicio()")

        if any(saludo in mensaje.lower() for saludo in ['hola', 'hi', 'hello', 'buenas']):
            self.cambiar_estado('menu_principal')
            return """¡Hola! Bienvenido a TecnoTienda 🛒

¿Qué te gustaría hacer?
1️⃣ Ver productos
2️⃣ Consultar pedido
3️⃣ Hablar con soporte

Responde con el número o dime qué necesitas."""

        return "¡Hola! Para comenzar, salúdame con 'hola' 😊"

    def estado_menu_principal(self, mensaje):
        print("📍 Ejecutando: estado_menu_principal()")
        mensaje_lower = mensaje.lower()

        if '1' in mensaje or 'productos' in mensaje_lower:
            self.cambiar_estado('navegando_productos')
            return """📱 Nuestros productos:

🔹 Smartphones
🔹 Laptops

¿Qué categoría te interesa?"""

        elif '2' in mensaje or 'pedido' in mensaje_lower:
            self.cambiar_estado('recopilando_datos')
            self.datos_sesion['tipo_consulta'] = 'pedido'
            return "Para consultar tu pedido, necesito tu número de orden o email de compra."

        elif '3' in mensaje or 'soporte' in mensaje_lower:
            return "Te pondremos en contacto con un asesor."

        elif 'menu' in mensaje_lower:
            return """¿Qué te gustaría hacer?
1️⃣ Ver productos
2️⃣ Consultar pedido
3️⃣ Hablar con soporte"""

        else:
            return """No entendí tu selección. Por favor elige:
1️⃣ Ver productos
2️⃣ Consultar pedido
3️⃣ Hablar con soporte"""

    def estado_navegando_productos(self, mensaje):
        print("📍 Ejecutando: estado_navegando_productos()")
        mensaje_lower = mensaje.lower()

        if 'smartphones' in mensaje_lower or 'teléfonos' in mensaje_lower or 'celulares' in mensaje_lower:
            self.datos_sesion['categoria'] = 'smartphones'
            productos_texto = self.mostrar_productos('smartphones')
            self.cambiar_estado('proceso_pedido')
            return f"""📱 Smartphones disponibles:
{productos_texto}

¿Cuál te interesa? Escribe el número del producto o 'menu' para volver."""

        elif 'laptops' in mensaje_lower or 'computadoras' in mensaje_lower:
            self.datos_sesion['categoria'] = 'laptops'
            productos_texto = self.mostrar_productos('laptops')
            self.cambiar_estado('proceso_pedido')
            return f"""💻 Laptops disponibles:
{productos_texto}

¿Cuál te interesa? Escribe el número del producto o 'menu' para volver."""

        elif 'menu' in mensaje_lower:
            self.cambiar_estado('menu_principal')
            return """¿Qué te gustaría hacer?
1️⃣ Ver productos
2️⃣ Consultar pedido
3️⃣ Hablar con soporte"""

        else:
            return """¿Qué categoría te interesa?
🔹 Smartphones
🔹 Laptops

O escribe 'menu' para volver al menú principal."""

    def estado_proceso_pedido(self, mensaje):
        print("📍 Ejecutando: estado_proceso_pedido()")
        mensaje_lower = mensaje.lower()

        if 'menu' in mensaje_lower:
            self.cambiar_estado('menu_principal')
            return """¿Qué te gustaría hacer?
1️⃣ Ver productos
2️⃣ Consultar pedido
3️⃣ Hablar con soporte"""

        # Procesar selección de producto
        try:
            numero_producto = int(mensaje.strip()) - 1
            categoria = self.datos_sesion.get('categoria')

            if categoria and 0 <= numero_producto < len(self.productos[categoria]):
                producto = self.productos[categoria][numero_producto]
                self.datos_sesion['producto_seleccionado'] = producto
                self.cambiar_estado('recopilando_datos')
                self.datos_sesion['tipo_consulta'] = 'compra'

                return f"""✅ Has seleccionado: {producto['nombre']} - ${producto['precio']}

Para procesar tu pedido necesito algunos datos:
Por favor, ingresa tu nombre completo:"""

        except (ValueError, IndexError):
            pass

        return """Por favor selecciona un producto escribiendo su número, o escribe 'menu' para volver al menú principal."""

    def estado_recopilando_datos(self, mensaje):
        print("📍 Ejecutando: estado_recopilando_datos()")

        tipo_consulta = self.datos_sesion.get('tipo_consulta')

        if tipo_consulta == 'compra':
            if 'nombre' not in self.datos_sesion:
                self.datos_sesion['nombre'] = mensaje
                return "Perfecto. Ahora necesito tu email:"

            elif 'email' not in self.datos_sesion:
                self.datos_sesion['email'] = mensaje
                return "Excelente. Por último, tu dirección de envío:"

            elif 'direccion' not in self.datos_sesion:
                self.datos_sesion['direccion'] = mensaje
                self.cambiar_estado('confirmacion')
                producto = self.datos_sesion['producto_seleccionado']

                return f"""📋 Resumen de tu pedido:

👤 Nombre: {self.datos_sesion['nombre']}
📧 Email: {self.datos_sesion['email']}
📍 Dirección: {self.datos_sesion['direccion']}
🛍️ Producto: {producto['nombre']}
💰 Precio: ${producto['precio']}

¿Confirmas tu pedido? (Sí/No)"""

        elif tipo_consulta == 'pedido':
            # Simular consulta de pedido
            self.cambiar_estado('menu_principal')
            return f"""📦 Estado de tu pedido para: {mensaje}

Pedido #12345
Estado: En tránsito 🚚
Fecha estimada de entrega: Mañana

¿Necesitas algo más? Escribe 'menu' para volver al menú principal."""

        return "No entendí. ¿Puedes repetir la información?"

    def estado_confirmacion(self, mensaje):
        print("📍 Ejecutando: estado_confirmacion()")
        mensaje_lower = mensaje.lower()

        if 'si' in mensaje_lower or 'sí' in mensaje_lower or 'confirmo' in mensaje_lower:
            # Limpiar datos de sesión para nuevo pedido
            producto = self.datos_sesion['producto_seleccionado']
            self.datos_sesion.clear()
            self.cambiar_estado('menu_principal')

            return f"""🎉 ¡Pedido confirmado!

Tu pedido de {producto['nombre']} ha sido procesado exitosamente.
Número de pedido: #PED{hash(str(producto)) % 10000}

¿Hay algo más en lo que pueda ayudarte?
1️⃣ Ver más productos
2️⃣ Consultar pedido
3️⃣ Hablar con soporte"""

        elif 'no' in mensaje_lower:
            self.datos_sesion.clear()
            self.cambiar_estado('menu_principal')
            return """❌ Pedido cancelado.

¿Te gustaría ver otros productos o hay algo más en lo que pueda ayudarte?

1️⃣ Ver productos
2️⃣ Consultar pedido
3️⃣ Hablar con soporte"""

        else:
            return "Por favor responde 'Sí' para confirmar o 'No' para cancelar el pedido."

    def mostrar_productos(self, categoria):
        """Genera texto con lista de productos de una categoría"""
        productos_texto = ""
        for i, producto in enumerate(self.productos[categoria], 1):
            productos_texto += f"{i}. {producto['nombre']} - ${producto['precio']}\n"
        return productos_texto

    def error_estado_desconocido(self):
        print("❌ [ERROR] Estado desconocido")
        return "Ha ocurrido un error. Reiniciando..."


# Código principal para ejecutar el chatbot
def ejecutar_chatbot():
    print("=" * 60)
    print("🤖 CHATBOT TECNOTIENDA - DEMO SIMPLIFICADA")
    print("=" * 60)
    print("Instrucciones:")
    print("- Escribe 'hola' para comenzar")
    print("- Escribe 'salir' en cualquier momento para terminar")
    print("- Los mensajes de DEBUG te muestran cómo cambian los estados")
    print("=" * 60)

    chatbot = FlujoChatbot()

    while True:
        print(f"\n🎯 ESTADO ACTUAL: {chatbot.estado_actual}")
        mensaje_usuario = input("\n👤 Tú: ").strip()

        if mensaje_usuario.lower() in ['salir', 'exit', 'quit']:
            print("\n👋 ¡Hasta luego! Gracias por usar TecnoTienda")
            break

        if not mensaje_usuario:
            print("⚠️ Por favor escribe algo...")
            continue

        respuesta = chatbot.procesar_mensaje(mensaje_usuario)
        print(f"\n🤖 Bot: {respuesta}")

# Ejecutar el chatbot
ejecutar_chatbot()
# Out:
# ...
# 🤖 CHATBOT TECNOTIENDA - DEMO SIMPLIFICADA
# ...
# Instrucciones:
# - Escribe 'hola' para comenzar
# - Escribe 'salir' en cualquier momento para terminar
# - Los mensajes de DEBUG te muestran cómo cambian los estados
# ...
#
# 🎯 ESTADO ACTUAL: inicio
#
# 👤 Tú: Hola querido
#
# 🤖 [ESTADO ACTUAL]: inicio
# 📨 [MENSAJE RECIBIDO]: Hola querido
# 💾 [DATOS SESIÓN]: {}
# --------------------------------------------------
# 📍 Ejecutando: estado_inicio()
# 🔄 [CAMBIO DE ESTADO]: inicio → menu_principal
#
# 🤖 Bot: ¡Hola! Bienvenido a TecnoTienda 🛒
#
# ¿Qué te gustaría hacer?
# 1️⃣ Ver productos
# 2️⃣ Consultar pedido
# 3️⃣ Hablar con soporte
#
# Responde con el número o dime qué necesitas.
#
# 🎯 ESTADO ACTUAL: menu_principal
#
# 👤 Tú: 1
#
# 🤖 [ESTADO ACTUAL]: menu_principal
# 📨 [MENSAJE RECIBIDO]: 1
# 💾 [DATOS SESIÓN]: {}
# --------------------------------------------------
# 📍 Ejecutando: estado_menu_principal()
# 🔄 [CAMBIO DE ESTADO]: menu_principal → navegando_productos
#
# 🤖 Bot: 📱 Nuestros productos:
#
# ...

# %% [markdown]
# **Validación y Manejo de Errores**

# %%
class ValidadorFlujo:
    def __init__(self):
        self.intentos_usuario = {}
        self.max_intentos = 3

    def validar_entrada(self, mensaje, tipo_validacion, usuario_id="default"):
        """Valida entrada del usuario según el tipo requerido"""

        if usuario_id not in self.intentos_usuario:
            self.intentos_usuario[usuario_id] = 0

        self.intentos_usuario[usuario_id] += 1

        if tipo_validacion == 'email':
            if re.match(r'^[^@]+@[^@]+\.[^@]+$', mensaje):
                self.intentos_usuario[usuario_id] = 0  # Reset
                return True, mensaje

        elif tipo_validacion == 'numero_pedido':
            if re.match(r'^#?\d{6,}$', mensaje):
                self.intentos_usuario[usuario_id] = 0
                return True, mensaje.replace('#', '')

        elif tipo_validacion == 'opcion_menu':
            if mensaje in ['1', '2', '3', '4']:
                self.intentos_usuario[usuario_id] = 0
                return True, mensaje

        # Si llegamos acá, la validación falló
        if self.intentos_usuario[usuario_id] >= self.max_intentos:
            self.intentos_usuario[usuario_id] = 0
            return False, "Demasiados intentos fallidos. Volviendo al menú principal."

        return False, f"Formato incorrecto. Intentos restantes: {self.max_intentos - self.intentos_usuario[usuario_id]}"

# %%
# Ejemplo uso validador.

validador = ValidadorFlujo()

# Validar entrada de email
while True:
    # Ingresa tu email
    mensaje = input("Ingresa tu email: ")
    valido, respuesta = validador.validar_entrada(mensaje, 'email')
    print(respuesta)
    if valido:
        break

# %% [markdown]
# # Ejercicio.
#
# Implentar el validador de datos al Chabot anterior para la Dirección, email y Nombre.
#
# Ayuda: Modificar la clase Flujo Chatbot, para que reciba como parametro la clase ValidadorFLujo de manera que pueda usar los metodos de esta.

# %% [markdown]
# ###Creando un bot en Telegram
# #### Configuración Inicial
#
# **Paso 1: Crear Bot en Telegram**
# 1. Buscar @BotFather en Telegram
# 2. Enviar `/newbot`
# 3. Seguir instrucciones para nombrar el bot
# 4. Guardar el TOKEN que te proporciona
#
# **Paso 2: Instalación de Dependencias**
# ```bash
# pip install python-telegram-bot requests

# %% [markdown]
# #### Código Base para Bot de Telegram

# %%
pip install python-telegram-bot requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.3/702.3 kB 9.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# #### Código Adicional para Funciones Avanzadas

# %% [markdown]
# ## Proyecto Hands-On: Chatbot de Consulta de Insumos para Telegram
#
# ### Descripción del Proyecto
#
# Crearemos un chatbot que permita a los usuarios consultar disponibilidad de insumos médicos, hacer pedidos básicos y obtener información sobre productos.

# %%
telegram_token = "8149851764:AAHpOP34Ip0XeWTpYlXKXqZH8w8GN1mATEI"

# %%
# Paso 1: Instalar la librería
# !pip install pyTelegramBotAPI
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 7.4 MB/s eta 0:00:00
# ...

# %%
# Paso 2: Importar librerías
import telebot
import time

# Paso 3: Configurar el token
TOKEN = '8149851764:AAHpOP34Ip0XeWTpYlXKXqZH8w8GN1mATEI'  # Reemplaza con tu token real
bot = telebot.TeleBot(TOKEN)

# Paso 4: Definir la función que responde "Hola"
@bot.message_handler(func=lambda message: True)
def send_hello(message):
    bot.reply_to(message, "Hola querido como dice que le va?")

# Paso 5: Iniciar el bot
print("Bot iniciado...")
print("Presiona Ctrl+C para detener el bot")

try:
    # Polling continuo
    bot.polling(none_stop=True)
except KeyboardInterrupt:
    print("\nBot detenido")
    bot.stop_polling()

# Versión alternativa: Solo responder al comando /start
"""
@bot.message_handler(commands=['start'])
def send_welcome(message):
    bot.reply_to(message, "Hola")

# Para usar esta versión, comenta las líneas anteriores
# y descomenta este bloque
"""
# Out:
# Bot iniciado...
# Presiona Ctrl+C para detener el bot
# ---------------------------------------------------------------------------
# ApiTelegramException                      Traceback (most recent call last)
# <ipython-input-46-d1d4fd3cf4a1> in <cell line: 0>()
#      18 try:
#      19     # Polling continuo
# ---> 20     bot.polling(none_stop=True)
#      21 except KeyboardInterrupt:
#      22     print("\nBot detenido")
#
# /usr/local/lib/python3.11/dist-packages/telebot/__init__.py in polling(self, non_stop, skip_pending, interval, timeout, long_polling_timeout, logger_level, allowed_updates, none_stop, restart_on_change, path_to_watch)
#    1193             self._setup_change_detector(path_to_watch)
#    1194
# -> 1195         logger.info('Starting your bot with username: [@%s]', self.user.username)
#    1196
#    1197         if self.threaded:
#
# /usr/local/lib/python3.11/dist-packages/telebot/__init__.py in user(self)
#     304         """
# ...
